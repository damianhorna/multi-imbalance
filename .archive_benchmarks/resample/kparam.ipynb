# %%
from collections import defaultdict
import numpy as np
import pandas as pd
from sklearn.metrics import recall_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelBinarizer
from IPython.core.display import display
from sklearn.model_selection import StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from tqdm import tqdm_notebook

from multi_imbalance.ensemble.soup_bagging import SOUPBagging
from multi_imbalance.resampling.soup import SOUP
from multi_imbalance.resampling.mdo import MDO
from multi_imbalance.resampling.global_cs import GlobalCS

from imblearn.metrics import geometric_mean_score
from imblearn.over_sampling import SMOTE
from multi_imbalance.resampling.spider import SPIDER3

from sklearn.neighbors import KNeighborsClassifier
import warnings
import logging
from multi_imbalance.utils.data import load_arff_datasets
from multi_imbalance.utils.min_int_maj import maj_int_min
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)
warnings.filterwarnings('ignore')

from IPython.display import clear_output
clear_output(wait=True)
# Out:
# Using TensorFlow backend.
# /home/plutasnyy/git/multi-imbalance/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/plutasnyy/git/multi-imbalance/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/plutasnyy/git/multi-imbalance/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/plutasnyy/git/multi-imbalance/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/plutasnyy/git/multi-imbalance/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/plutasnyy/git/multi-imbalance/venv/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/plutasnyy/git/multi-imbalance/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/plutasnyy/git/multi-imbalance/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/plutasnyy/git/multi-imbalance/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/plutasnyy/git/multi-imbalance/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/plutasnyy/git/multi-imbalance/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/plutasnyy/git/multi-imbalance/venv/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# def green_valid_backgroud(s):
#     correct = ['1czysty-cut', '2delikatne-cut', '3mocniej-cut','4delikatne-bezover-cut', 'cmc', 'dermatology', 'new_ecoli','new_vehicle','thyroid-newthyroid']
#     return ['background-color: green' if v in correct else '' for v in list(s.index)]
# 


def bold_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['font-weight: bold' if v else '' for v in is_max]
    
def print_scores(scores, name, only_read_dt = False, columns=None, base=None):
    df = pd.DataFrame(scores).T
    if only_read_dt:
        df = df.iloc[4:]
    if columns is not None:
        df = df[columns]
    if base is not None:
        df = pd.merge(base,df, left_index=True, right_index=True)
    df2 = df.style.apply(bold_max, axis=1)
    display(df2)
    
    with open(f'{name}_main.tex','w') as tf:
        tf.write(df.to_latex())
    df.to_csv(f'{name}_main.csv')
    
    df.fillna(df.median(), inplace=True)
    df_median = pd.DataFrame(df.mean().sort_values(ascending=False),columns=['Mean G-mean'])
    display(df_median)
    df_meanrank = pd.DataFrame(df.rank(axis=1,ascending=False).mean().sort_values(),columns=['Mean rank'])
    display(df_meanrank)
    
    with open(f'{name}_median.tex','w') as tf:
        tf.write(df_median.to_latex())
    df_median.to_csv(f'{name}_median.csv')
    with open(f'{name}_meanrank.tex','w') as tf:
        tf.write(df_meanrank.to_latex())
    df_meanrank.to_csv(f'{name}_meanrank.csv')
# print_scores(scores_knn)

# %%
def resample_data(resample, seed, X_train, y_train, no_classes, dataset_name):
    if resample == 'base':
        X_train_resampled, y_train_resampled = X_train, y_train
    elif 'soup' in resample:
        k = int(resample[-1])
        soup = SOUP(k=k)
        X_train_resampled, y_train_resampled = soup.fit_transform(np.copy(X_train), np.copy(y_train), maj_int_min=maj_int_min[dataset_name])
    elif resample=='global':
        global_cs = GlobalCS()
        X_train_resampled, y_train_resampled = global_cs.fit_transform(np.copy(X_train), np.copy(y_train), shuffle=False)
    elif resample=='smote':
        smote = SMOTE(random_state=seed)
        X_train_resampled, y_train_resampled = smote.fit_sample(np.copy(X_train), np.copy(y_train))
    elif 'mdo' in resample:
        k=int(resample[-1])
        frac = float(resample[0])/10
        mdo = MDO(k=k, k1_frac=frac, seed=seed)
        X_train_resampled, y_train_resampled = mdo.fit_transform(np.copy(X_train), np.copy(y_train), maj_int_min=maj_int_min[dataset_name])
    elif resample=='spider':
        cost = np.ones((no_classes, no_classes))
        np.fill_diagonal(cost, 0)
        clf = SPIDER3(k=5, cost=cost, majority_classes=maj_int_min[dataset_name]['maj'], intermediate_classes=maj_int_min[dataset_name]['int'], minority_classes=maj_int_min[dataset_name]['min'])
        X_train_resampled, y_train_resampled = clf.fit_transform(X_train.astype(np.float64), y_train)
    elif 'soupbg' in resample or 'mrbbag' in resample:
        # SOUP Bagging does it by itself
        X_train_resampled, y_train_resampled = X_train, y_train
    else:
        raise ValueError(f'Bad type{resample}')
    return X_train_resampled, y_train_resampled



def test_resampling(res, dataset_values, dataset_name):
    X, y, scale_index = dataset_values.data, dataset_values.target, dataset_values.cat_length

    no_classes = np.unique(y).size
    minority_class = maj_int_min[dataset_name]['min']
    result_data = defaultdict(int)
    run_data = defaultdict(lambda: defaultdict(list)) # {metric: {run_number: [scores]}}
    for i in range(10):
        skf = StratifiedKFold(n_splits=5, shuffle=True,random_state=i)
        for train_index, test_index in skf.split(X, y):
            X_train, X_test = X[train_index], X[test_index]
            y_train, y_test = y[train_index], y[test_index]
            if scale_index > 0:
                normalizer = StandardScaler().fit(X_train[:,:scale_index])
    
                X_train[:,:scale_index] = normalizer.transform(X_train[:,:scale_index])
                X_test[:,:scale_index] = normalizer.transform(X_test[:,:scale_index])
            X_train_resampled, y_train_resampled = resample_data(res, i, X_train, y_train, no_classes, dataset_name)

            # for clf_name in ['knn']:
            for clf_name in ['knn','tree']:
                if clf_name == 'knn':
                    clf = KNeighborsClassifier(n_neighbors=5)
                elif clf_name == 'tree':
                    clf = DecisionTreeClassifier(random_state=i)
                    
                if  'soupbg005' in res:
                    vote_classifier = SOUPBagging(clf, n_classifiers=5)
                    clf = vote_classifier
                elif  'soupbg015' in res:
                    vote_classifier = SOUPBagging(clf, n_classifiers=15)
                    clf = vote_classifier
                elif  'soupbg030' in res:
                    vote_classifier = SOUPBagging(clf, n_classifiers=30)
                    clf = vote_classifier
                elif  'soupbg050' in res:
                    vote_classifier = SOUPBagging(clf, n_classifiers=50)
                    clf = vote_classifier
                elif  'soupbg100' in res:
                    vote_classifier = SOUPBagging(clf, n_classifiers=100)
                    clf = vote_classifier
                # elif res == 'mrbbag005':
                    
                    
                clf.fit(X_train_resampled, y_train_resampled)
                if 'soupbg' in res:
                    for strategy in ['average','optimistic','pessimistic','mixed', 'global']:
                        y_pred = clf.predict(X_test, strategy=strategy, maj_int_min=maj_int_min[dataset_name])
                        gmean = geometric_mean_score(y_test, y_pred, correction=0.001)
                        minority_gmean = geometric_mean_score(y_test, y_pred,labels=minority_class, correction=0.001)
                        avg_acc = np.mean(recall_score(y_test, y_pred, average=None))
                        run_data['g_mean_{}_{}'.format(clf_name, strategy)][str(i)].append(gmean)
                        run_data['g_mean_{}_minority_{}'.format(clf_name, strategy)][str(i)].append(minority_gmean)
                else:
                    y_pred = clf.predict(X_test)
                    gmean = geometric_mean_score(y_test, y_pred, correction=0.001)
                    minority_gmean = geometric_mean_score(y_test, y_pred,labels=minority_class, correction=0.001)
                    avg_acc = np.mean(recall_score(y_test, y_pred, average=None))
                    run_data['g_mean_{}'.format(clf_name)][str(i)].append(gmean)
                    run_data['g_mean_{}_minority'.format(clf_name)][str(i)].append(minority_gmean)
                # run_data['avg_acc_{}'.format(clf_name)][str(i)].append(avg_acc)
    
    def get_score_from_metric(run_data, metric):
        runs = run_data[metric]
        runs_scores_list = list(runs.values()) #[[one run k-foledscores],[..]]
        result = np.mean(list(map(np.mean, runs_scores_list)))
        return result
            
    for metric_name, metric_values in run_data.items():
        result_data[metric_name] = get_score_from_metric(run_data, metric_name)
        
    return result_data


def provide_test_and_get_scores(datasets, clf_res_names):
    scores = defaultdict(lambda: defaultdict(dict))
    for dataset_name, dataset_values in tqdm_notebook(datasets.items(),total=len(datasets), desc='1st loop'):
        for resample in clf_res_names:
            result_data = test_resampling(resample, dataset_values, dataset_name)
            for key in result_data:
                scores[key][dataset_name][resample] = round(result_data[key],4)
    return scores

# clf_res_names =['base','soup','soupbg005','soupbg015','soupbg030','soupbg050','soupbg100']
clf_res_names =['soup3','soup5','soup7','3mdo3','3mdo5','3mdo7','5mdo3','5mdo5','5mdo7','7mdo3','7mdo5','7mdo7']
datasets = load_arff_datasets(return_cat_length=True)
scores = provide_test_and_get_scores(datasets, clf_res_names)
# Out:
# HBox(children=(IntProgress(value=0, description='1st loop', max=19, style=ProgressStyle(description_width='ini…

# %% [markdown]
# #### Gmean knn

# %%
columns = [i for i in clf_res_names if 'soup' in i]
print_scores(scores['g_mean_knn'], 'g_mean_knn_soup',columns=columns)
# Out:
# <style  type="text/css" >
#     #T_27424cb2_331e_11ea_96dc_14dda906faf8row0_col0 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row1_col1 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row2_col0 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row3_col2 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row4_col2 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row5_col2 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row6_col0 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row7_col2 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row8_col0 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row9_col0 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row10_col2 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row11_col0 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row12_col0 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row13_col0 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row14_col1 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row15_col0 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row16_col2 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row17_col2 {
#             font-weight:  bold;
#         }    #T_27424cb2_331e_11ea_96dc_14dda906faf8row18_col0 {
#             font-weight:  bold;
#         }</style><table id="T_27424cb2_331e_11ea_96dc_14dda906faf8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >soup3</th>        <th class="col_heading level0 col1" >soup5</th>        <th class="col_heading level0 col2" >soup7</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_27424cb2_331e_11ea_96dc_14dda906faf8level0_row0" class="row_heading level0 row0" >1czysty-cut</th>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row0_col0" class="data row0 col0" >0.9607</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row0_col1" class="data row0 col1" >0.9559</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row0_col2" class="data row0 col2" >0.9514</td>
#             </tr>
#             <tr>
#                         <th id="T_27424cb2_331e_11ea_96dc_14dda906faf8level0_row1" class="row_heading level0 row1" >2delikatne-cut</th>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row1_col0" class="data row1 col0" >0.7851</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row1_col1" class="data row1 col1" >0.7896</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row1_col2" class="data row1 col2" >0.7894</td>
#             </tr>
#             <tr>
#                         <th id="T_27424cb2_331e_11ea_96dc_14dda906faf8level0_row2" class="row_heading level0 row2" >3mocniej-cut</th>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row2_col0" class="data row2 col0" >0.5489</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row2_col1" class="data row2 col1" >0.5467</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row2_col2" class="data row2 col2" >0.547</td>
#             </tr>
#             <tr>
#                         <th id="T_27424cb2_331e_11ea_96dc_14dda906faf8level0_row3" class="row_heading level0 row3" >4delikatne-bezover-cut</th>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row3_col0" class="data row3 col0" >0.8855</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row3_col1" class="data row3 col1" >0.8892</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row3_col2" class="data row3 col2" >0.8918</td>
#             </tr>
#             <tr>
#                         <th id="T_27424cb2_331e_11ea_96dc_14dda906faf8level0_row4" class="row_heading level0 row4" >balance-scale</th>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row4_col0" class="data row4 col0" >0.6317</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row4_col1" class="data row4 col1" >0.6673</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row4_col2" class="data row4 col2" >0.6786</td>
#             </tr>
#             <tr>
#                         <th id="T_27424cb2_331e_11ea_96dc_14dda906faf8level0_row5" class="row_heading level0 row5" >car</th>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row5_col0" class="data row5 col0" >0.5315</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row5_col1" class="data row5 col1" >0.5666</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row5_col2" class="data row5 col2" >0.6069</td>
#             </tr>
#             <tr>
#                         <th id="T_27424cb2_331e_11ea_96dc_14dda906faf8level0_row6" class="row_heading level0 row6" >cleveland</th>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row6_col0" class="data row6 col0" >0.2038</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row6_col1" class="data row6 col1" >0.199</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row6_col2" class="data row6 col2" >0.1979</td>
#             </tr>
#             <tr>
#                         <th id="T_27424cb2_331e_11ea_96dc_14dda906faf8level0_row7" class="row_heading level0 row7" >cleveland_v2</th>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row7_col0" class="data row7 col0" >0.2479</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row7_col1" class="data row7 col1" >0.2475</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row7_col2" class="data row7 col2" >0.248</td>
#             </tr>
#             <tr>
#                         <th id="T_27424cb2_331e_11ea_96dc_14dda906faf8level0_row8" class="row_heading level0 row8" >cmc</th>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row8_col0" class="data row8 col0" >0.4801</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row8_col1" class="data row8 col1" >0.4788</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row8_col2" class="data row8 col2" >0.4774</td>
#             </tr>
#             <tr>
#                         <th id="T_27424cb2_331e_11ea_96dc_14dda906faf8level0_row9" class="row_heading level0 row9" >dermatology</th>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row9_col0" class="data row9 col0" >0.9485</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row9_col1" class="data row9 col1" >0.9441</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row9_col2" class="data row9 col2" >0.944</td>
#             </tr>
#             <tr>
#                         <th id="T_27424cb2_331e_11ea_96dc_14dda906faf8level0_row10" class="row_heading level0 row10" >flare</th>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row10_col0" class="data row10 col0" >0.4926</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row10_col1" class="data row10 col1" >0.4948</td>
#                         <td id="T_27424cb2_331e_11ea_96dc_14dda906faf8row10_col2" class="data row10 col2" >0.4951</td>
#             </tr>
#             <tr>
#                         <th id="T_27424cb2_331e_11ea_96dc_14dda906faf8level0_row11" class="row_heading level0
#        Mean G-mean
# soup7     0.636284
# soup5     0.634995
# soup3     0.634726
#        Mean rank
# soup3   1.842105
# soup5   2.052632
# soup7   2.105263

# %% [markdown]
# #### Gmean minority knn

# %%
columns = [i for i in clf_res_names if 'soup' in i]
print_scores(scores['g_mean_knn_minority'], 'g_mean_knn_soup_minority',columns=columns)
# Out:
# <style  type="text/css" >
#     #T_281618ee_331e_11ea_96dc_14dda906faf8row0_col0 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row0_col1 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row0_col2 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row1_col2 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row2_col1 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row3_col2 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row4_col2 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row5_col2 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row6_col0 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row7_col0 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row7_col1 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row7_col2 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row8_col2 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row9_col0 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row9_col1 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row9_col2 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row10_col0 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row11_col0 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row12_col0 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row13_col0 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row14_col1 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row15_col2 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row16_col2 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row17_col2 {
#             font-weight:  bold;
#         }    #T_281618ee_331e_11ea_96dc_14dda906faf8row18_col2 {
#             font-weight:  bold;
#         }</style><table id="T_281618ee_331e_11ea_96dc_14dda906faf8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >soup3</th>        <th class="col_heading level0 col1" >soup5</th>        <th class="col_heading level0 col2" >soup7</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_281618ee_331e_11ea_96dc_14dda906faf8level0_row0" class="row_heading level0 row0" >1czysty-cut</th>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row0_col2" class="data row0 col2" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ee_331e_11ea_96dc_14dda906faf8level0_row1" class="row_heading level0 row1" >2delikatne-cut</th>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row1_col0" class="data row1 col0" >0.8025</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row1_col1" class="data row1 col1" >0.8175</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row1_col2" class="data row1 col2" >0.8225</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ee_331e_11ea_96dc_14dda906faf8level0_row2" class="row_heading level0 row2" >3mocniej-cut</th>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row2_col0" class="data row2 col0" >0.5942</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row2_col1" class="data row2 col1" >0.6158</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row2_col2" class="data row2 col2" >0.6108</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ee_331e_11ea_96dc_14dda906faf8level0_row3" class="row_heading level0 row3" >4delikatne-bezover-cut</th>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row3_col0" class="data row3 col0" >0.9558</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row3_col1" class="data row3 col1" >0.9725</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row3_col2" class="data row3 col2" >0.9842</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ee_331e_11ea_96dc_14dda906faf8level0_row4" class="row_heading level0 row4" >balance-scale</th>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row4_col0" class="data row4 col0" >0.6478</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row4_col1" class="data row4 col1" >0.7527</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row4_col2" class="data row4 col2" >0.7727</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ee_331e_11ea_96dc_14dda906faf8level0_row5" class="row_heading level0 row5" >car</th>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row5_col0" class="data row5 col0" >0.4923</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row5_col1" class="data row5 col1" >0.5638</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row5_col2" class="data row5 col2" >0.6156</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ee_331e_11ea_96dc_14dda906faf8level0_row6" class="row_heading level0 row6" >cleveland</th>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row6_col0" class="data row6 col0" >0.162</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row6_col1" class="data row6 col1" >0.1578</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row6_col2" class="data row6 col2" >0.1564</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ee_331e_11ea_96dc_14dda906faf8level0_row7" class="row_heading level0 row7" >cleveland_v2</th>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row7_col0" class="data row7 col0" >0.2019</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row7_col1" class="data row7 col1" >0.2019</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row7_col2" class="data row7 col2" >0.2019</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ee_331e_11ea_96dc_14dda906faf8level0_row8" class="row_heading level0 row8" >cmc</th>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row8_col0" class="data row8 col0" >0.5387</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row8_col1" class="data row8 col1" >0.5357</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row8_col2" class="data row8 col2" >0.5511</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ee_331e_11ea_96dc_14dda906faf8level0_row9" class="row_heading level0 row9" >dermatology</th>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row9_col0" class="data row9 col0" >0.995</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row9_col1" class="data row9 col1" >0.995</td>
#                         <td id="T_281618ee_331e_11ea_96dc_14dda906faf8row9_col2" class="data row9 col2" >0.995</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ee_331e_11ea_96dc_14dda906faf
#        Mean G-mean
# soup7     0.669421
# soup5     0.665237
# soup3     0.657032
#        Mean rank
# soup7   1.736842
# soup5   2.052632
# soup3   2.210526

# %% [markdown]
# #### Gmean tree

# %%
columns = [i for i in clf_res_names if 'soup' in i]
print_scores(scores['g_mean_tree'], 'g_mean_tree_soup',columns=columns)
# Out:
# <style  type="text/css" >
#     #T_281618ef_331e_11ea_96dc_14dda906faf8row0_col2 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row1_col2 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row2_col2 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row3_col2 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row4_col2 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row5_col2 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row6_col2 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row7_col2 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row8_col1 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row9_col0 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row10_col1 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row11_col2 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row12_col0 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row13_col0 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row14_col2 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row15_col0 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row16_col2 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row17_col2 {
#             font-weight:  bold;
#         }    #T_281618ef_331e_11ea_96dc_14dda906faf8row18_col0 {
#             font-weight:  bold;
#         }</style><table id="T_281618ef_331e_11ea_96dc_14dda906faf8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >soup3</th>        <th class="col_heading level0 col1" >soup5</th>        <th class="col_heading level0 col2" >soup7</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_281618ef_331e_11ea_96dc_14dda906faf8level0_row0" class="row_heading level0 row0" >1czysty-cut</th>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row0_col0" class="data row0 col0" >0.9574</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row0_col1" class="data row0 col1" >0.9557</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row0_col2" class="data row0 col2" >0.9578</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ef_331e_11ea_96dc_14dda906faf8level0_row1" class="row_heading level0 row1" >2delikatne-cut</th>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row1_col0" class="data row1 col0" >0.775</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row1_col1" class="data row1 col1" >0.786</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row1_col2" class="data row1 col2" >0.7919</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ef_331e_11ea_96dc_14dda906faf8level0_row2" class="row_heading level0 row2" >3mocniej-cut</th>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row2_col0" class="data row2 col0" >0.5664</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row2_col1" class="data row2 col1" >0.5653</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row2_col2" class="data row2 col2" >0.574</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ef_331e_11ea_96dc_14dda906faf8level0_row3" class="row_heading level0 row3" >4delikatne-bezover-cut</th>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row3_col0" class="data row3 col0" >0.8749</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row3_col1" class="data row3 col1" >0.8894</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row3_col2" class="data row3 col2" >0.8933</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ef_331e_11ea_96dc_14dda906faf8level0_row4" class="row_heading level0 row4" >balance-scale</th>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row4_col0" class="data row4 col0" >0.5575</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row4_col1" class="data row4 col1" >0.6091</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row4_col2" class="data row4 col2" >0.6098</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ef_331e_11ea_96dc_14dda906faf8level0_row5" class="row_heading level0 row5" >car</th>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row5_col0" class="data row5 col0" >0.8795</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row5_col1" class="data row5 col1" >0.8723</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row5_col2" class="data row5 col2" >0.8911</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ef_331e_11ea_96dc_14dda906faf8level0_row6" class="row_heading level0 row6" >cleveland</th>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row6_col0" class="data row6 col0" >0.1028</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row6_col1" class="data row6 col1" >0.1171</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row6_col2" class="data row6 col2" >0.1199</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ef_331e_11ea_96dc_14dda906faf8level0_row7" class="row_heading level0 row7" >cleveland_v2</th>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row7_col0" class="data row7 col0" >0.1422</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row7_col1" class="data row7 col1" >0.1469</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row7_col2" class="data row7 col2" >0.1564</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ef_331e_11ea_96dc_14dda906faf8level0_row8" class="row_heading level0 row8" >cmc</th>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row8_col0" class="data row8 col0" >0.4755</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row8_col1" class="data row8 col1" >0.4827</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row8_col2" class="data row8 col2" >0.4783</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ef_331e_11ea_96dc_14dda906faf8level0_row9" class="row_heading level0 row9" >dermatology</th>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row9_col0" class="data row9 col0" >0.9458</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row9_col1" class="data row9 col1" >0.9368</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row9_col2" class="data row9 col2" >0.9319</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ef_331e_11ea_96dc_14dda906faf8level0_row10" class="row_heading level0 row10" >flare</th>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row10_col0" class="data row10 col0" >0.546</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row10_col1" class="data row10 col1" >0.5481</td>
#                         <td id="T_281618ef_331e_11ea_96dc_14dda906faf8row10_col2" class="data row10 col2" >0.5442</td>
#             </tr>
#             <tr>
#                         <th id="T_281618ef_331e_11ea_96dc_14dda906faf8level0_row11" class="row_heading level0
#        Mean G-mean
# soup7     0.656916
# soup5     0.654374
# soup3     0.649932
#        Mean rank
# soup7   1.631579
# soup5   2.157895
# soup3   2.210526

# %% [markdown]
# #### Gmean minority tree

# %%
columns = [i for i in clf_res_names if 'soup' in i]
print_scores(scores['g_mean_tree_minority'], 'g_mean_tree_soup_minority',columns=columns)
# Out:
# <style  type="text/css" >
#     #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row0_col2 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row1_col2 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row2_col2 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row3_col2 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row4_col1 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row5_col2 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row6_col2 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row7_col2 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row8_col2 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row9_col0 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row10_col1 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row11_col2 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row12_col0 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row12_col1 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row13_col2 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row14_col1 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row15_col1 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row16_col2 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row17_col2 {
#             font-weight:  bold;
#         }    #T_2a22b5c0_331e_11ea_96dc_14dda906faf8row18_col1 {
#             font-weight:  bold;
#         }</style><table id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >soup3</th>        <th class="col_heading level0 col1" >soup5</th>        <th class="col_heading level0 col2" >soup7</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8level0_row0" class="row_heading level0 row0" >1czysty-cut</th>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row0_col0" class="data row0 col0" >0.9542</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row0_col1" class="data row0 col1" >0.9567</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row0_col2" class="data row0 col2" >0.9642</td>
#             </tr>
#             <tr>
#                         <th id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8level0_row1" class="row_heading level0 row1" >2delikatne-cut</th>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row1_col0" class="data row1 col0" >0.67</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row1_col1" class="data row1 col1" >0.7008</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row1_col2" class="data row1 col2" >0.7183</td>
#             </tr>
#             <tr>
#                         <th id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8level0_row2" class="row_heading level0 row2" >3mocniej-cut</th>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row2_col0" class="data row2 col0" >0.4292</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row2_col1" class="data row2 col1" >0.4458</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row2_col2" class="data row2 col2" >0.4483</td>
#             </tr>
#             <tr>
#                         <th id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8level0_row3" class="row_heading level0 row3" >4delikatne-bezover-cut</th>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row3_col0" class="data row3 col0" >0.8833</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row3_col1" class="data row3 col1" >0.9217</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row3_col2" class="data row3 col2" >0.9425</td>
#             </tr>
#             <tr>
#                         <th id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8level0_row4" class="row_heading level0 row4" >balance-scale</th>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row4_col0" class="data row4 col0" >0.3684</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row4_col1" class="data row4 col1" >0.4509</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row4_col2" class="data row4 col2" >0.4451</td>
#             </tr>
#             <tr>
#                         <th id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8level0_row5" class="row_heading level0 row5" >car</th>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row5_col0" class="data row5 col0" >0.9344</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row5_col1" class="data row5 col1" >0.9399</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row5_col2" class="data row5 col2" >0.9639</td>
#             </tr>
#             <tr>
#                         <th id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8level0_row6" class="row_heading level0 row6" >cleveland</th>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row6_col0" class="data row6 col0" >0.0701</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row6_col1" class="data row6 col1" >0.0841</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row6_col2" class="data row6 col2" >0.0842</td>
#             </tr>
#             <tr>
#                         <th id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8level0_row7" class="row_heading level0 row7" >cleveland_v2</th>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row7_col0" class="data row7 col0" >0.0959</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row7_col1" class="data row7 col1" >0.1017</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row7_col2" class="data row7 col2" >0.1095</td>
#             </tr>
#             <tr>
#                         <th id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8level0_row8" class="row_heading level0 row8" >cmc</th>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row8_col0" class="data row8 col0" >0.5067</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row8_col1" class="data row8 col1" >0.5096</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row8_col2" class="data row8 col2" >0.5321</td>
#             </tr>
#             <tr>
#                         <th id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8level0_row9" class="row_heading level0 row9" >dermatology</th>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row9_col0" class="data row9 col0" >0.98</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row9_col1" class="data row9 col1" >0.95</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row9_col2" class="data row9 col2" >0.955</td>
#             </tr>
#             <tr>
#                         <th id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8level0_row10" class="row_heading level0 row10" >flare</th>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row10_col0" class="data row10 col0" >0.5996</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row10_col1" class="data row10 col1" >0.6002</td>
#                         <td id="T_2a22b5c0_331e_11ea_96dc_14dda906faf8row10_col2" class="data row10 col2" >0.586</td>
#             </tr>
#             <tr>
#        Mean G-mean
# soup7     0.656500
# soup5     0.649011
# soup3     0.636074
#        Mean rank
# soup7   1.578947
# soup5   1.815789
# soup3   2.605263

# %% [markdown]
# #### Gmean knn

# %%
columns = [i for i in clf_res_names if 'mdo' in i]
print_scores(scores['g_mean_knn'], 'gmean_mdo_knn',columns=columns)
# Out:
# <style  type="text/css" >
#     #T_2b1b9514_331e_11ea_96dc_14dda906faf8row0_col8 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row1_col1 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row2_col2 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row3_col2 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row4_col0 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row5_col1 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row6_col3 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row7_col3 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row8_col6 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row9_col3 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row10_col2 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row11_col0 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row12_col0 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row13_col6 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row14_col1 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row15_col1 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row15_col3 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row16_col2 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row17_col0 {
#             font-weight:  bold;
#         }    #T_2b1b9514_331e_11ea_96dc_14dda906faf8row18_col1 {
#             font-weight:  bold;
#         }</style><table id="T_2b1b9514_331e_11ea_96dc_14dda906faf8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >3mdo3</th>        <th class="col_heading level0 col1" >3mdo5</th>        <th class="col_heading level0 col2" >3mdo7</th>        <th class="col_heading level0 col3" >5mdo3</th>        <th class="col_heading level0 col4" >5mdo5</th>        <th class="col_heading level0 col5" >5mdo7</th>        <th class="col_heading level0 col6" >7mdo3</th>        <th class="col_heading level0 col7" >7mdo5</th>        <th class="col_heading level0 col8" >7mdo7</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2b1b9514_331e_11ea_96dc_14dda906faf8level0_row0" class="row_heading level0 row0" >1czysty-cut</th>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row0_col0" class="data row0 col0" >0.9781</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row0_col1" class="data row0 col1" >0.9771</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row0_col2" class="data row0 col2" >0.9777</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row0_col3" class="data row0 col3" >0.9781</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row0_col4" class="data row0 col4" >0.9777</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row0_col5" class="data row0 col5" >0.9772</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row0_col6" class="data row0 col6" >0.9794</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row0_col7" class="data row0 col7" >0.9794</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row0_col8" class="data row0 col8" >0.9795</td>
#             </tr>
#             <tr>
#                         <th id="T_2b1b9514_331e_11ea_96dc_14dda906faf8level0_row1" class="row_heading level0 row1" >2delikatne-cut</th>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row1_col0" class="data row1 col0" >0.7937</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row1_col1" class="data row1 col1" >0.7978</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row1_col2" class="data row1 col2" >0.7835</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row1_col3" class="data row1 col3" >0.7905</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row1_col4" class="data row1 col4" >0.7762</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row1_col5" class="data row1 col5" >0.7749</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row1_col6" class="data row1 col6" >0.7562</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row1_col7" class="data row1 col7" >0.7542</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row1_col8" class="data row1 col8" >0.7551</td>
#             </tr>
#             <tr>
#                         <th id="T_2b1b9514_331e_11ea_96dc_14dda906faf8level0_row2" class="row_heading level0 row2" >3mocniej-cut</th>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row2_col0" class="data row2 col0" >0.5799</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row2_col1" class="data row2 col1" >0.5922</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row2_col2" class="data row2 col2" >0.6064</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row2_col3" class="data row2 col3" >0.5779</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row2_col4" class="data row2 col4" >0.5748</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row2_col5" class="data row2 col5" >0.567</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row2_col6" class="data row2 col6" >0.5524</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row2_col7" class="data row2 col7" >0.5443</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row2_col8" class="data row2 col8" >0.5431</td>
#             </tr>
#             <tr>
#                         <th id="T_2b1b9514_331e_11ea_96dc_14dda906faf8level0_row3" class="row_heading level0 row3" >4delikatne-bezover-cut</th>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row3_col0" class="data row3 col0" >0.8644</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row3_col1" class="data row3 col1" >0.8703</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row3_col2" class="data row3 col2" >0.8715</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row3_col3" class="data row3 col3" >0.862</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row3_col4" class="data row3 col4" >0.8616</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row3_col5" class="data row3 col5" >0.8625</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row3_col6" class="data row3 col6" >0.8407</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row3_col7" class="data row3 col7" >0.8444</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row3_col8" class="data row3 col8" >0.8478</td>
#             </tr>
#             <tr>
#                         <th id="T_2b1b9514_331e_11ea_96dc_14dda906faf8level0_row4" class="row_heading level0 row4" >balance-scale</th>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row4_col0" class="data row4 col0" >0.6788</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row4_col1" class="data row4 col1" >0.3931</td>
#                         <td id="T_2b1b9514_331e_11ea_96dc_14dda906faf8row4_col2" class="data row4 col2" >0.3301</td>
#        Mean G-mean
# 3mdo3     0.607847
# 3mdo5     0.598521
# 3mdo7     0.590832
# 5mdo3     0.584337
# 5mdo5     0.567026
# 5mdo7     0.560484
# 7mdo5     0.541416
# 7mdo3     0.540905
# 7mdo7     0.540732
#        Mean rank
# 3mdo5   2.921053
# 5mdo3   3.315789
# 3mdo7   3.710526
# 3mdo3   3.947368
# 5mdo5   5.263158
# 5mdo7   5.526316
# 7mdo3   6.473684
# 7mdo5   6.842105
# 7mdo7   7.000000

# %% [markdown]
# #### Gmean minority knn

# %%
columns = [i for i in clf_res_names if 'mdo' in i]
print_scores(scores['g_mean_knn_minority'], 'gmean_mdo_knn_minority',columns=columns)
# Out:
# <style  type="text/css" >
#     #T_2b1b9515_331e_11ea_96dc_14dda906faf8row0_col2 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row1_col1 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row2_col1 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row3_col1 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row4_col0 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row5_col1 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row6_col3 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row7_col3 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row8_col8 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row9_col0 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row9_col1 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row9_col2 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row9_col3 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row9_col4 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row9_col5 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row9_col6 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row9_col7 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row9_col8 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row10_col2 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row11_col0 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row12_col0 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row13_col1 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row14_col1 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row15_col3 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row16_col2 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row17_col0 {
#             font-weight:  bold;
#         }    #T_2b1b9515_331e_11ea_96dc_14dda906faf8row18_col1 {
#             font-weight:  bold;
#         }</style><table id="T_2b1b9515_331e_11ea_96dc_14dda906faf8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >3mdo3</th>        <th class="col_heading level0 col1" >3mdo5</th>        <th class="col_heading level0 col2" >3mdo7</th>        <th class="col_heading level0 col3" >5mdo3</th>        <th class="col_heading level0 col4" >5mdo5</th>        <th class="col_heading level0 col5" >5mdo7</th>        <th class="col_heading level0 col6" >7mdo3</th>        <th class="col_heading level0 col7" >7mdo5</th>        <th class="col_heading level0 col8" >7mdo7</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2b1b9515_331e_11ea_96dc_14dda906faf8level0_row0" class="row_heading level0 row0" >1czysty-cut</th>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row0_col0" class="data row0 col0" >0.9992</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row0_col1" class="data row0 col1" >0.9992</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row0_col3" class="data row0 col3" >0.9992</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row0_col4" class="data row0 col4" >0.9992</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row0_col5" class="data row0 col5" >0.9983</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row0_col6" class="data row0 col6" >0.995</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row0_col7" class="data row0 col7" >0.9992</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row0_col8" class="data row0 col8" >0.9983</td>
#             </tr>
#             <tr>
#                         <th id="T_2b1b9515_331e_11ea_96dc_14dda906faf8level0_row1" class="row_heading level0 row1" >2delikatne-cut</th>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row1_col0" class="data row1 col0" >0.7167</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row1_col1" class="data row1 col1" >0.725</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row1_col2" class="data row1 col2" >0.6825</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row1_col3" class="data row1 col3" >0.7033</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row1_col4" class="data row1 col4" >0.6667</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row1_col5" class="data row1 col5" >0.6533</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row1_col6" class="data row1 col6" >0.6167</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row1_col7" class="data row1 col7" >0.6025</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row1_col8" class="data row1 col8" >0.6108</td>
#             </tr>
#             <tr>
#                         <th id="T_2b1b9515_331e_11ea_96dc_14dda906faf8level0_row2" class="row_heading level0 row2" >3mocniej-cut</th>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row2_col0" class="data row2 col0" >0.4925</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row2_col1" class="data row2 col1" >0.5025</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row2_col2" class="data row2 col2" >0.4833</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row2_col3" class="data row2 col3" >0.4917</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row2_col4" class="data row2 col4" >0.41</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row2_col5" class="data row2 col5" >0.405</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row2_col6" class="data row2 col6" >0.3667</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row2_col7" class="data row2 col7" >0.3508</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row2_col8" class="data row2 col8" >0.3408</td>
#             </tr>
#             <tr>
#                         <th id="T_2b1b9515_331e_11ea_96dc_14dda906faf8level0_row3" class="row_heading level0 row3" >4delikatne-bezover-cut</th>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row3_col0" class="data row3 col0" >0.8167</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row3_col1" class="data row3 col1" >0.8458</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row3_col2" class="data row3 col2" >0.8433</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row3_col3" class="data row3 col3" >0.8142</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row3_col4" class="data row3 col4" >0.8133</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row3_col5" class="data row3 col5" >0.81</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row3_col6" class="data row3 col6" >0.775</td>
#                         <td id="T_2b1b9515_331e_11ea_96dc_14dda906faf8row3_col7" class="data row3 col
#        Mean G-mean
# 3mdo3     0.562653
# 3mdo5     0.549821
# 3mdo7     0.535463
# 5mdo3     0.534684
# 5mdo5     0.508411
# 5mdo7     0.499621
# 7mdo7     0.469953
# 7mdo5     0.469553
# 7mdo3     0.468600
#        Mean rank
# 3mdo5   2.578947
# 3mdo7   3.184211
# 5mdo3   3.368421
# 3mdo3   3.947368
# 5mdo5   4.631579
# 5mdo7   5.789474
# 7mdo3   7.000000
# 7mdo7   7.184211
# 7mdo5   7.315789

# %% [markdown]
# #### Gmean tree

# %%
columns = [i for i in clf_res_names if 'mdo' in i]
print_scores(scores['g_mean_tree'], 'gmean_tree_mdo',columns=columns)
# Out:
# <style  type="text/css" >
#     #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row0_col0 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row1_col3 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row2_col2 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row3_col1 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row4_col0 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row5_col1 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row6_col6 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row7_col1 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row8_col2 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row9_col3 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row10_col6 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row11_col0 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row12_col1 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row13_col1 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row14_col2 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row15_col1 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row16_col1 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row17_col0 {
#             font-weight:  bold;
#         }    #T_2cfd72c6_331e_11ea_96dc_14dda906faf8row18_col0 {
#             font-weight:  bold;
#         }</style><table id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >3mdo3</th>        <th class="col_heading level0 col1" >3mdo5</th>        <th class="col_heading level0 col2" >3mdo7</th>        <th class="col_heading level0 col3" >5mdo3</th>        <th class="col_heading level0 col4" >5mdo5</th>        <th class="col_heading level0 col5" >5mdo7</th>        <th class="col_heading level0 col6" >7mdo3</th>        <th class="col_heading level0 col7" >7mdo5</th>        <th class="col_heading level0 col8" >7mdo7</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8level0_row0" class="row_heading level0 row0" >1czysty-cut</th>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row0_col0" class="data row0 col0" >0.9646</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row0_col1" class="data row0 col1" >0.9634</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row0_col2" class="data row0 col2" >0.9616</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row0_col3" class="data row0 col3" >0.9639</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row0_col4" class="data row0 col4" >0.9626</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row0_col5" class="data row0 col5" >0.9614</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row0_col6" class="data row0 col6" >0.961</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row0_col7" class="data row0 col7" >0.9603</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row0_col8" class="data row0 col8" >0.9599</td>
#             </tr>
#             <tr>
#                         <th id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8level0_row1" class="row_heading level0 row1" >2delikatne-cut</th>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row1_col0" class="data row1 col0" >0.7668</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row1_col1" class="data row1 col1" >0.7597</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row1_col2" class="data row1 col2" >0.7613</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row1_col3" class="data row1 col3" >0.7729</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row1_col4" class="data row1 col4" >0.7544</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row1_col5" class="data row1 col5" >0.758</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row1_col6" class="data row1 col6" >0.7423</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row1_col7" class="data row1 col7" >0.74</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row1_col8" class="data row1 col8" >0.7416</td>
#             </tr>
#             <tr>
#                         <th id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8level0_row2" class="row_heading level0 row2" >3mocniej-cut</th>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row2_col0" class="data row2 col0" >0.5581</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row2_col1" class="data row2 col1" >0.5661</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row2_col2" class="data row2 col2" >0.594</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row2_col3" class="data row2 col3" >0.557</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row2_col4" class="data row2 col4" >0.5616</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row2_col5" class="data row2 col5" >0.5586</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row2_col6" class="data row2 col6" >0.5419</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row2_col7" class="data row2 col7" >0.5415</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row2_col8" class="data row2 col8" >0.535</td>
#             </tr>
#             <tr>
#                         <th id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8level0_row3" class="row_heading level0 row3" >4delikatne-bezover-cut</th>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row3_col0" class="data row3 col0" >0.8186</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row3_col1" class="data row3 col1" >0.8241</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row3_col2" class="data row3 col2" >0.8207</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row3_col3" class="data row3 col3" >0.8112</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row3_col4" class="data row3 col4" >0.8144</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row3_col5" class="data row3 col5" >0.8154</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row3_col6" class="data row3 col6" >0.7999</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row3_col7" class="data row3 col7" >0.8</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row3_col8" class="data row3 col8" >0.8037</td>
#             </tr>
#             <tr>
#                         <th id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8level0_row4" class="row_heading level0 row4" >balance-scale</th>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row4_col0" class="data row4 col0" >0.1704</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row4_col1" class="data row4 col1" >0.1654</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row4_col2" class="data row4 col2" >0.1588</td>
#                         <td id="T_2cfd72c6_331e_11ea_96dc_14dda906faf8row4_col3" class="data row4 col3" >0.1561
#        Mean G-mean
# 3mdo5     0.622653
# 3mdo3     0.620721
# 3mdo7     0.618837
# 5mdo3     0.616595
# 5mdo5     0.610495
# 7mdo3     0.610016
# 5mdo7     0.609016
# 7mdo7     0.607337
# 7mdo5     0.604747
#        Mean rank
# 3mdo5   2.894737
# 3mdo7   3.263158
# 3mdo3   3.473684
# 5mdo3   4.789474
# 5mdo7   5.210526
# 5mdo5   5.578947
# 7mdo3   6.342105
# 7mdo7   6.631579
# 7mdo5   6.815789

# %% [markdown]
# #### Gmean minority tree

# %%
columns = [i for i in clf_res_names if 'mdo' in i]
print_scores(scores['g_mean_tree_minority'], 'gmean_tree_mdo_minority',columns=columns)
# Out:
# <style  type="text/css" >
#     #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row0_col0 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row0_col3 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row1_col3 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row2_col0 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row3_col1 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row4_col0 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row5_col1 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row6_col6 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row7_col1 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row8_col2 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row9_col0 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row10_col6 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row11_col0 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row12_col0 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row12_col1 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row12_col2 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row12_col3 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row12_col4 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row12_col5 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row13_col1 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row14_col6 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row14_col7 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row15_col1 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row16_col1 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row17_col0 {
#             font-weight:  bold;
#         }    #T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row18_col0 {
#             font-weight:  bold;
#         }</style><table id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >3mdo3</th>        <th class="col_heading level0 col1" >3mdo5</th>        <th class="col_heading level0 col2" >3mdo7</th>        <th class="col_heading level0 col3" >5mdo3</th>        <th class="col_heading level0 col4" >5mdo5</th>        <th class="col_heading level0 col5" >5mdo7</th>        <th class="col_heading level0 col6" >7mdo3</th>        <th class="col_heading level0 col7" >7mdo5</th>        <th class="col_heading level0 col8" >7mdo7</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8level0_row0" class="row_heading level0 row0" >1czysty-cut</th>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row0_col0" class="data row0 col0" >0.9633</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row0_col1" class="data row0 col1" >0.9608</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row0_col2" class="data row0 col2" >0.955</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row0_col3" class="data row0 col3" >0.9633</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row0_col4" class="data row0 col4" >0.9592</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row0_col5" class="data row0 col5" >0.955</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row0_col6" class="data row0 col6" >0.9533</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row0_col7" class="data row0 col7" >0.9508</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row0_col8" class="data row0 col8" >0.9508</td>
#             </tr>
#             <tr>
#                         <th id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8level0_row1" class="row_heading level0 row1" >2delikatne-cut</th>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row1_col0" class="data row1 col0" >0.68</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row1_col1" class="data row1 col1" >0.6717</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row1_col2" class="data row1 col2" >0.6717</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row1_col3" class="data row1 col3" >0.695</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row1_col4" class="data row1 col4" >0.655</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row1_col5" class="data row1 col5" >0.6442</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row1_col6" class="data row1 col6" >0.61</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row1_col7" class="data row1 col7" >0.5958</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row1_col8" class="data row1 col8" >0.6067</td>
#             </tr>
#             <tr>
#                         <th id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8level0_row2" class="row_heading level0 row2" >3mocniej-cut</th>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row2_col0" class="data row2 col0" >0.4958</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row2_col1" class="data row2 col1" >0.485</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row2_col2" class="data row2 col2" >0.4808</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row2_col3" class="data row2 col3" >0.4883</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row2_col4" class="data row2 col4" >0.4192</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row2_col5" class="data row2 col5" >0.4058</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row2_col6" class="data row2 col6" >0.3667</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row2_col7" class="data row2 col7" >0.3667</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row2_col8" class="data row2 col8" >0.3442</td>
#             </tr>
#             <tr>
#                         <th id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8level0_row3" class="row_heading level0 row3" >4delikatne-bezover-cut</th>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row3_col0" class="data row3 col0" >0.7692</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row3_col1" class="data row3 col1" >0.7858</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row3_col2" class="data row3 col2" >0.775</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row3_col3" class="data row3 col3" >0.7508</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row3_col4" class="data row3 col4" >0.755</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row3_col5" class="data row3 col5" >0.7608</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row3_col6" class="data row3 col6" >0.7392</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8row3_col7" class="data row3 col7" >0.7258</td>
#                         <td id="T_2e3a4e2a_331e_11ea_96dc_14dda906faf8ro
#        Mean G-mean
# 3mdo5     0.580642
# 3mdo3     0.580374
# 3mdo7     0.573653
# 5mdo3     0.573374
# 5mdo5     0.559616
# 5mdo7     0.556589
# 7mdo3     0.553384
# 7mdo7     0.549784
# 7mdo5     0.548905
#        Mean rank
# 3mdo5   3.052632
# 3mdo3   3.526316
# 3mdo7   3.947368
# 5mdo3   4.000000
# 5mdo7   5.526316
# 5mdo5   5.868421
# 7mdo3   6.105263
# 7mdo7   6.394737
# 7mdo5   6.578947
